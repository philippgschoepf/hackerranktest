# %%
# This is a sample Notebook
# We recommend including the below cell in your notebooks so that candidates can easily install packages they need.

# %%
# If you'd like to install packages that aren't installed by default, list them here.
# This will ensure your notebook has all the dependencies and works everywhere

import sys
# !{sys.executable} -m pip install xgboost sklearn
# Out:
# Collecting xgboost
#   Downloading xgboost-1.1.0-py3-none-macosx_10_13_x86_64.macosx_10_14_x86_64.macosx_10_15_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 2.7 MB/s eta 0:00:01
# Processing /Users/philipp/Library/Caches/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074/sklearn-0.0-py2.py3-none-any.whl
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from xgboost) (1.17.4)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from sklearn) (0.20.2)
# Installing collected packages: xgboost, sklearn
# Successfully installed sklearn-0.0 xgboost-1.1.0
# WARNING: You are using pip version 20.0.2; however, version 20.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install --upgrade pip' command.

# %%
# Import libraries

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Small datasets can be added to the project directly and imported by referring to the file name
df = pd.read_csv("iris.csv")

# To import large datasets (over 5MBs), you can host them externally and import by directly referring to the URL.
# For example
# df = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/data/iris.csv')

# %%
# %matplotlib inline
from pandas.plotting import andrews_curves

andrews_curves(df, 'Name')

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
x = df.loc[:, df.columns != 'Name']
y = df['Name']
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(x, y)
#RandomForestClassifier(...)
#print(clf.predict([[0, 0, 0, 0]]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
clf.predict([[5.5,2.3,4,1.3]])
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
for name, importance in zip(y, clf.feature_importances_):
    print(name, "=", importance)
# Out:
# Iris-setosa = 0.1403382019817557
# Iris-setosa = 0.023309670697114582
# Iris-setosa = 0.37710300714852274
# Iris-setosa = 0.45924912017260694
